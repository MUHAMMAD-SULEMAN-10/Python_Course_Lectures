# %% [markdown]
# #Agenda
#
# 1. Control Statements (code flow )
#
#    1----
#
#    2----
#
#    3----
#
#    4----
#
#    5----
#
#    we want to execute particular lines from the code to perform a task. here we make decions which lines are going to execute following the code flow.
#
# 2. if
#
# 3. if else
#
# 4. single line if else

# %% [markdown]
# #Control statement:
#
#
#
# 1. decision control
#
# --->if
#
# --->if else
#
# ---> if else if
#
# ---> single line if else
#
#
# 2. Match case
#
# 3. Iterative control(TCS)= Trnasfer Control Statement
#
# ---> Break
#
# ---> Continue
#
# ---> Pause

# %% [markdown]
# # if
#
#
# if is a keyword.
#
#
# if condition:
#
#     .....
#
#     .....
#
#   ----
#
#   here we follow indentation means we need to give some gap/space after : colon indentation block start.
#
#   ### Note: all statements will follow the indentation block in one format.

# %%
if 5 > 3:

  #if block start
  print("Hello WORLD!") #here we are following indentation after : colon
  print("Muhammad Suleman")
  print("Python Advance Course")
# Out:
# Hello WORLD!
# Muhammad Suleman
# Python Advance Course

# %% [markdown]
# ### Write a program to check whether a given number is positive or non positive.

# %%
x = int(input("Enter a number"))

if x > 0:

  print("Positive")

if x <= 0:

  print("Non Positive")
# Out:
# Enter a number-7
# Non Positive

# %% [markdown]
# # if else
#
# has two keywords
#
# if condition:
#
#
#   .....
#
#   .....
#
#   .....
#
#   .....
#
#   else:
#
#   ....
#
#   ....
#
# if first block of code is true then next else block will not execute.
#
# ### Note: Only one block must execute.

# %% [markdown]
# # Write a program to check whether a given number is positive or non positive?

# %%
x = int (input("Enter a number"))

if x > 0:

  print("Positive")

else:
   print("Non Positive")

#This program is more efficient but How? think few minutes
# Out:
# Enter a number-6
# Non Positive

# %% [markdown]
# # if elif else
#
# 1. if first condition is true the first block will execute
#
# 2. if false then it will go to elif condition, if first wrong or elif all wrong then at last else will run must.
#
# if condition:
#
# .....
#
# .....
#
#
# elif condition:
#
#
# ....
#
# ....
#
# elif condition:
#
# ....
#
# ....
#
#
# elif condition:
#
# ....
#
# ....
#
#
# else:
#
# ....
#
# ....

# %% [markdown]
# # Write a program to print grade obtained in a test. Tkse marks obtained from user and display the grade.

# %%
x = int(input("Enter marks"))

if x>90 and x<=100:
  print("Grade A")

elif x>80 and x<=90:
  print("Grade B")

elif x>70 and x<=80:
  print("Grade C")

elif x>60 and x<=70:

 print("Grade D")

elif x>=50 and x<=60:
 print("Grade E")

else:
  print("Grade F")
# Out:
# Enter marks67
# Grade D

# %% [markdown]
# # single line if else
#
# syntax:
#
# ### code1 if condition else code2
#
# 1. here if condition is true then code1 execute
# and if condition is flase then code2 execute
#
# x = code1
#
#
# 2. single line if else is an expression
#    but if else is not an expression.
#
# 3. it works like an conditionla operator ? like in other languages c , c++ , Js

# %% [markdown]
# # write a python program to check whether a given numner is positive or non positive?

# %%
x = int(input("Enter a number"))

print("Positive") if x>0 else print("Non Positive")
# Out:
# Enter a number5
# Positive

# %% [markdown]
# # Python program related to number checking. This one checks whether a given number is even or odd.

# %%
num = int(input("Enter a number: "))

print(f"{num} is Even.") if num % 2 == 0 else print(f"{num} is Odd.")
# Out:
# Enter a number: 5
# 5 is Odd.

# %% [markdown]
# # Nested if else
#
#
# if condition:
#
#  ....
#
#  ....
#
#
#      if condition:
#
#      ....
#
#      ....
#
#      else:
#
#
#      ....
#
#      ....
#
# else:
#
# ....
#
# ....
