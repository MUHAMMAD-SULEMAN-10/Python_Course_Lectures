# %% [markdown]
# #Print Statement

# %%
print("Hello World")
# print is a keyword
# Out:
# Hello World

# %%
print('Icode Guru')
# Out:
# Icode Guru

# %%
Print("Print P is Capital")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-4566f570dc9c> in <cell line: 0>()
# ----> 1 Print("Print P is Capital")
#
# NameError: name 'Print' is not defined

# %%
print "Hello World"
# Out:
#   File "<ipython-input-4-2e860ebf713e>", line 1
#     print "Hello World"
#     ^
# SyntaxError: Missing parentheses in call to 'print'. Did you mean print(...)?

# %%
print ("Good
 Morning")
# Out:
#   File "<ipython-input-5-16a03769e993>", line 1
#     print ("Good
#            ^
# SyntaxError: unterminated string literal (detected at line 1)

# %%
"Good Eveninig"
print("Hi")
# Out:
# Hi

# %%
print(""" Hello World
Hello Word
New Yeork """)
# To print multilines
# Out:
#  Hello World
# Hello Word
# New Yeork

# %% [markdown]
# #Comments

# %%
#Say Hello To Studensts
# print("Say Hello to STUDENTS")
# Out:
# Say Hello to STUDENTS

# %% [markdown]
# #Multilines Comments

# %%
"""Say Hi To Students
 You hello To Studensts
"""

print ("Hi Students")
# Out:
# Hi Students

# %% [markdown]
# #More Exceptional Cases in print cases

# %%
print("Hi my name is "Suleman" ")
# Out:
#   File "<ipython-input-13-3e366fc8314b>", line 1
#     print("Hi my name is "Suleman" ")
#           ^
# SyntaxError: invalid syntax. Perhaps you forgot a comma?

# %%
print ('Hi my name is "Suleman"')
# Out:
# Hi my name is "Suleman"

# %%
print ("Hi my name is 'Suleman' ")
# Out:
# Hi my name is 'Suleman'

# %%
print (""" Hi my name is "Suleman" """)
# Out:
#  Hi my name is "Suleman"

# %%
print (""" Hi my name is "Suleman"! """)
# Out:
#  Hi my name is "Suleman"!

# %% [markdown]
# ##Header <---Mark Down

# %% [markdown]
# #Python as Calculator

# %%
444 + 33
# Out:
# 477

# %%
444*6
# Out:
# 2664

# %%
445/34
# Out:
# 13.088235294117647

# %%
122%2
#Modilo operator which gives you remender
# Out:
# 0

# %%
22**2 #power of 22 raised to 2
# Out:
# 484

# %%
444*3
print ('hello')
# Out:
# hello

# %%
print (444*3)
print("Hello ")
# Out:
# 1332
# Hello

# %%
print("444*3")
print("Hello World")
# Out:
# 444*3
# Hello World

# %% [markdown]
# #Variables in python

# %%
x  = 10
print(x)

#varivale name should start with alphabates
#variable name should not contain any special character like @ % ! * ()
#variable name can contain no but it can not start with it
#variable nema can contain capital letter but it is not recommended practice
# Out:
# 10

# %%
y  = 20
print (y)
# Out:
# 20

# %%
print (x , y)
# Out:
# 10 20

# %% [markdown]
# #Variable examples

# %%
#accepted varibales

ten  = 10
ten_num  = 10
tenNumber = 10

# %%
ten* = 10 #error
ten%number  = 10 #error due to operator
#not recommended practice

# %%
10ten = 10 #error

# %%
_ten  = 10 #Hidden variable
#using for it internal use no any user will use it

# %%
Ten = 10 #it is acceptable but it is not recommended way
#it is actually consider a calss

# %%
# ten number  = 10 // will throw an error due to gap
ten_number  = 10

# %% [markdown]
# #Data Types

# %% [markdown]
# #Inter

# %%
a  = 10
type(a)
# Out:
# int

# %%
a = 20
print (type(a))
# Out:
# <class 'int'>

# %% [markdown]
# #Floats number containings decimals numbers

# %%
pi = 3.14
type(pi)
# Out:
# float

# %%
x = 12.4
type (x)
# Out:
# float

# %%
pi = 44/3
pi
# Out:
# 14.666666666666666

# %%
type (pi)
# Out:
# float

# %% [markdown]
# #Complex Numbers - are imginary numbers

# %%
a = 2*3j
a
#j is like an imaginary here
# Out:
# 6j

# %%
a = 7*3j
a
type(a)
# Out:
# complex

# %%
a.real # to get ral value
# Out:
# 0.0

# %%
a.imag #imaginary value
# Out:
# 21.0

# %% [markdown]
# #Dnaymic Typing

# %% [markdown]
# ```
# int a = 20;
# ```

# %%
#this is called dynapic typing

a = 20
print(type(a))
a = 22.4
print(type(a))
a = "M Suleman"
print(type(a))
# Out:
# <class 'int'>
# <class 'float'>
# <class 'str'>

# %%
print(a)
# Out:
# M Suleman

# %% [markdown]
# #Strong Typing in Python --- float and integer are not concate

# %%
"Day"   + 1
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-60-b7d0154bee04> in <cell line: 0>()
# ----> 1 "Day"   + 1
#
# TypeError: can only concatenate str (not "int") to str

# %%
"Day" + "1"
# Out:
# 'Day1'

# %%
"22" + "22"
# Out:
# '2222'

# %%
22+22
# Out:
# 44

# %%
"Muhamamd " +"Suleman"
# Out:
# 'Muhamamd Suleman'

# %%
'M ' + "Suleman"
# Out:
# 'M Suleman'

# %%
"22" + 22
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-66-2e2b19d89d15> in <cell line: 0>()
# ----> 1 "22" + 22
#
# TypeError: can only concatenate str (not "int") to str

# %%
22 + '22'
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-67-da8dd2dcee3a> in <cell line: 0>()
# ----> 1 22 + '22'
#
# TypeError: unsupported operand type(s) for +: 'int' and 'str'

# %% [markdown]
# #Danymic concatination

# %%
print("Welcome to class of java language ")
# Out:
# Welcome to class of java language

# %%
language ='python'#dynampic value access and pus is use to concatenate //allowed but rarely used
print("welcome to calss of " + language  +  " Language")
# Out:
# welcome to calss of python Language

# %%
language = "Java"
print("welcome to calss of {language} Language")
# Out:
# welcome to calss of {language} Language

# %%
language ="python"#//another method current standard method very used
print(f"welcome to calss of { language } Language") #f is used for formated string or f string
# Out:
# welcome to calss of python Language

# %%
num  = 'first'
language  = 'python'
print("today is {} class of {} language " .format(num , language))#another method
# Out:
# today is first class of python language

# %% [markdown]
# #sum of two variables

# %%
a   =  20
b  = 44
c  =  a +  b
print(f"The sum of two numbers a: {a} and b: {b} is equal {c}")
# Out:
# The sum of two numbers a: 20 and b: 44 is equal 64

# %% [markdown]
# #Boolean Data Type

# %%
one = True
two = False
print(type(one))
print(type(two))
# Out:
# <class 'bool'>
# <class 'bool'>

# %%
class_start_at = 1500
you_came_at=1600
you_came_at < class_start_at
# Out:
# False

# %%
class_start_at = 1500
you_came_at=1600
you_understand_All_concepts = you_came_at < class_start_at
print(f"You understand everything?{you_understand_All_concepts}")
# Out:
# You understand everything?False

# %%
class_start_at = 3
you_came_at= 2
you_understand_All_concepts = you_came_at < class_start_at
print(f"You understand everything?{you_understand_All_concepts}")
# Out:
# You understand everything?True

# %%
is_raining = True
is_umberella_availabe = False
go_to_college = is_raining == is_umberella_availabe
go_to_college
# Out:
# False

# %% [markdown]
# #Douts

# %%
"My name is \"Suleman\" Afzal" #string agr start ke ha to usko end b krna ha
# Out:
# 'My name is "Suleman" Afzal'

# %%
"Muhamamd "  + "Suleman "  + "Afzal"
# Out:
# 'Muhamamd Suleman Afzal'
