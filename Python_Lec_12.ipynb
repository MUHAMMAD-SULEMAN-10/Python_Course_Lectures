# %% [markdown]
# # Agenda:
#
# ## Recursion
#
#
# 1. What is recursion ?
#
# 2. Recursion Tree
#
# 3. How to appraoch recursive solution ?

# %% [markdown]
# ## What is recursion ?
#
# Function calling itself is called recursion.
#
# ### Syntax:
#
#       def f1( ):
#
#          ....
#          ....
#
#          f1( ) # fun calling itself
#
#          ....
#          ....
#          ....

# %% [markdown]
# # Example Program related to Rcusrsion

# %%
def f1 (n):

  if n==1:
    return 1

  s = n+f1(n-1)
  return s

r =f1(3)

print(r)
# Out:
# 6

# %% [markdown]
# # Recursion Tree
#
# ### further will cover with the help of diagram then we will easily understand the process of recursion How it works during program execution.

# %% [markdown]
# ## How to appraoch recursive solution ?
#
# 1. In recursion, problem is solved in terms of problem itself.
#
# 2. each time recursive function call to itself for little simpler version of the origional problem .
